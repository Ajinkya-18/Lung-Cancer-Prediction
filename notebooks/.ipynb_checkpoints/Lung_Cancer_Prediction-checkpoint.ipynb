# %% [markdown]
# # Lung Cancer Prediction

# %% [markdown]
# ## Import Dependencies

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Loading and Preprocessing

# %%
df = pd.read_csv('../data/cancer patient data sets.csv', index_col=0)

# %%
df = df.drop(['Patient Id', 'Gender'], axis=1)

# %%
df.head()
# Out:
#        Age  Air Pollution  Alcohol use  Dust Allergy  OccuPational Hazards  \
# index
# 0       33              2            4             5                     4
# 1       17              3            1             5                     3
# 2       35              4            5             6                     5
# 3       37              7            7             7                     7
# 4       46              6            8             7                     7
#
#        Genetic Risk  chronic Lung Disease  Balanced Diet  Obesity  Smoking  \
# index
# 0                 3                     2              2        4        3
# 1                 4                     2              2        2        2
# 2                 5                     4              6        7        2
# 3                 6                     7              7        7        7
# 4                 7                     6              7        7        8
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1000 non-null   int64
#  1   Air Pollution             1000 non-null   int64
#  2   Alcohol use               1000 non-null   int64
#  3   Dust Allergy              1000 non-null   int64
#  4   OccuPational Hazards      1000 non-null   int64
#  5   Genetic Risk              1000 non-null   int64
#  6   chronic Lung Disease      1000 non-null   int64
#  7   Balanced Diet             1000 non-null   int64
#  8   Obesity                   1000 non-null   int64
#  9   Smoking                   1000 non-null   int64
#  10  Passive Smoker            1000 non-null   int64
#  11  Chest Pain                1000 non-null   int64
#  12  Coughing of Blood         1000 non-null   int64
#  13  Fatigue                   1000 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age  Air Pollution  Alcohol use  Dust Allergy  \
# count  1000.000000      1000.0000  1000.000000   1000.000000
# mean     37.174000         3.8400     4.563000      5.165000
# std      12.005493         2.0304     2.620477      1.980833
# min      14.000000         1.0000     1.000000      1.000000
# 25%      27.750000         2.0000     2.000000      4.000000
# 50%      36.000000         3.0000     5.000000      6.000000
# 75%      45.000000         6.0000     7.000000      7.000000
# max      73.000000         8.0000     8.000000      8.000000
#
#        OccuPational Hazards  Genetic Risk  chronic Lung Disease  \
# count           1000.000000   1000.000000           1000.000000
# mean               4.840000      4.580000              4.380000
# std                2.107805      2.126999              1.848518
# min                1.000000      1.000000              1.000000
# 25%                3.000000      2.000000              3.000000
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Air Pollution', 'Alcohol use', 'Dust Allergy',
#        'OccuPational Hazards', 'Genetic Risk', 'chronic Lung Disease',
#        'Balanced Diet', 'Obesity', 'Smoking', 'Passive Smoker', 'Chest Pain',
#        'Coughing of Blood', 'Fatigue', 'Weight Loss', 'Shortness of Breath',
#        'Wheezing', 'Swallowing Difficulty', 'Clubbing of Finger Nails',
#        'Frequent Cold', 'Dry Cough', 'Snoring', 'Level'],
#       dtype='object')

# %%
df['Level'].hist()
plt.show()

# %% [markdown]
# ## Feature Encoding

# %%
from sklearn.preprocessing import OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.feature_selection import mutual_info_regression, SelectKBest
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler

std_scaler = StandardScaler()
ord_enc = OrdinalEncoder()
ord_enc.set_output(transform='pandas')
# Out:
# OrdinalEncoder()

# %%
scaler_cols = df.drop(['Level'], axis=1).columns.tolist()

transformers = [('standard scaler', StandardScaler(), scaler_cols)]

col_transformer = ColumnTransformer(transformers, 
                                    remainder='passthrough', sparse_threshold=0, n_jobs=6, 
                                    verbose=True, verbose_feature_names_out=False)
col_transformer.set_output(transform='pandas')
# Out:
# ColumnTransformer(n_jobs=6, remainder='passthrough', sparse_threshold=0,
#                   transformers=[('standard scaler', StandardScaler(),
#                                  ['Age', 'Air Pollution', 'Alcohol use',
#                                   'Dust Allergy', 'OccuPational Hazards',
#                                   'Genetic Risk', 'chronic Lung Disease',
#                                   'Balanced Diet', 'Obesity', 'Smoking',
#                                   'Passive Smoker', 'Chest Pain',
#                                   'Coughing of Blood', 'Fatigue', 'Weight Loss',
#                                   'Shortness of Breath', 'Wheezing',
#                                   'Swallowing Difficulty',
#                                   'Clubbing of Finger Nails', 'Frequent Cold',
#                                   'Dry Cough', 'Snoring'])],
#                   verbose=True, verbose_feature_names_out=False)

# %%
X = df.drop(['Level'], axis=1)
Y = df['Level']

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, 
                                                    random_state=42, shuffle=True)

# %%
col_transformer.fit(x_train)
# Out:
# ColumnTransformer(n_jobs=6, remainder='passthrough', sparse_threshold=0,
#                   transformers=[('standard scaler', StandardScaler(),
#                                  ['Age', 'Air Pollution', 'Alcohol use',
#                                   'Dust Allergy', 'OccuPational Hazards',
#                                   'Genetic Risk', 'chronic Lung Disease',
#                                   'Balanced Diet', 'Obesity', 'Smoking',
#                                   'Passive Smoker', 'Chest Pain',
#                                   'Coughing of Blood', 'Fatigue', 'Weight Loss',
#                                   'Shortness of Breath', 'Wheezing',
#                                   'Swallowing Difficulty',
#                                   'Clubbing of Finger Nails', 'Frequent Cold',
#                                   'Dry Cough', 'Snoring'])],
#                   verbose=True, verbose_feature_names_out=False)

# %%
# from joblib import dump
# with open('../models/col_transformer_fitted.joblib', 'wb') as f:
#     dump(col_transformer, f)

# %%
ord_enc.fit(y_train.values.reshape(-1,1))
# Out:
# OrdinalEncoder()

# %%
# from joblib import dump 
# with open('../models/ordinal_encoder_fitted.joblib', 'wb') as f:
#     dump(ord_enc, f)

# %%
x_train_new = col_transformer.transform(x_train)
x_test_new = col_transformer.transform(x_test)
y_train_new = ord_enc.transform(y_train.values.reshape(-1, 1))
y_test_new = ord_enc.transform(y_test.values.reshape(-1, 1))

# %% [markdown]
# ## Features Correlation Visualization

# %%
x_train_new.shape
# Out:
# (750, 22)

# %%
y_train_new.shape
# Out:
# (750, 1)

# %%
y_train_new = y_train_new.rename(columns={'x0':'Level'})

# %%
df1 = x_train_new.join(y_train_new)

# %%
corr_mat = df1.corr()

# %%
corr_mat.shape
# Out:
# (23, 23)

# %%
plt.figure(figsize=(16, 16))
sns.heatmap(corr_mat, annot=True, fmt='.2f')
plt.show()

# %% [markdown]
# ## Model Selection and Training

# %%
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# %%
svc = SVC()
rfc = RandomForestClassifier()
lr = LogisticRegression()
dtc = DecisionTreeClassifier()

# %%
x_train_new.shape
# Out:
# (750, 22)

# %%
y_train_new.shape
# Out:
# (750, 1)

# %%
svc.fit(x_train_new, y_train_new.values.ravel())
rfc.fit(x_train_new, y_train_new.values.ravel())
lr.fit(x_train_new, y_train_new.values.ravel())
dtc.fit(x_train_new, y_train_new.values.ravel())
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.metrics import accuracy_score, mean_squared_error

# %%
svc_preds = svc.predict(x_test_new)
rfc_preds = rfc.predict(x_test_new)
lr_preds = lr.predict(x_test_new)
dtc_preds = dtc.predict(x_test_new)

# %%
svc_acc = accuracy_score(y_test_new, svc_preds)
rfc_acc = accuracy_score(y_test_new, rfc_preds)
lr_acc = accuracy_score(y_test_new, lr_preds)
dtc_acc = accuracy_score(y_test_new, dtc_preds)

# %%
print(f'SVC Accuracy: {svc_acc * 100} %')
print(f'RFR Accuracy: {rfc_acc * 100} %')
print(f'LR Prediction Accuracy: {lr_acc * 100} %')
print(f'DTC Prediction Accuracy: {dtc_acc * 100} %')
# Out:
# SVC Accuracy: 100.0 %
# RFR Accuracy: 100.0 %
# LR Prediction Accuracy: 100.0 %
# DTC Prediction Accuracy: 100.0 %

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))

axs[0,1].scatter(y_test_new, svc_preds, color='green')
axs[0,1].set_title('SVC')

axs[1,0].scatter(y_test_new, rfc_preds, color='yellow')
axs[1,0].set_title('RFR')

axs[1,1].scatter(y_test_new, lr_preds, color='red')
axs[1,1].set_title('LR')


axs[0,0].scatter(y_test_new, dtc_preds, color='orange')
axs[0,0].set_title('DTC')

plt.show()

# %%
from sklearn.metrics import confusion_matrix
lr_cm = confusion_matrix(y_test_new, lr_preds)
rfc_cm = confusion_matrix(y_test_new, rfc_preds)
svc_cm = confusion_matrix(y_test_new, svc_preds)
dtc_cm = confusion_matrix(y_test_new, dtc_preds)

# %%
plt.title('Logistic Regression - Confusion Matrix')
sns.heatmap(lr_cm, annot=True, cmap='Blues', fmt='g')
plt.savefig('../reports/lr_cm.png')
plt.show()

# %%
plt.title('Support Vector Machine - Confusion Matrix')
sns.heatmap(svc_cm, annot=True, cmap='Blues', fmt='g')
# plt.savefig('../reports/svc_cm.png')
plt.show()

# %%
plt.title('Random Forest Regressor - Confusion Matrix')
sns.heatmap(rfc_cm, annot=True, cmap='Blues', fmt='g')
plt.savefig('../reports/rfr_cm.png')
plt.show()

# %%
plt.title('Decision Tree Classifier - Confusion Matrix')
sns.heatmap(dtc_cm, annot=True, cmap='Blues', fmt='g')
# plt.savefig('../reports/dtc_cm.png')
plt.show()

# %% [markdown]
# ## Exporting, Testing and Deploying the Trained Models

# %%
# from pickle import dump
# with open('../model/knc_model.pkl', 'wb') as f:
#     dump(knc, f, protocol=5)

# %%
from pickle import load
with open('../model/knc_model.pkl', 'rb') as f:
    knc_loaded = load(f)

# %%
# # save the fitted scaler
# from pickle import dump
# with open('../model/fitted_std_scaler.pkl', 'wb') as f:
#     dump(std_scaler, f)

# %%
def get_value_range(df) -> tuple:
    features_range = {}
    for col in df.columns:
        features_range[col] = (min(df[col]), max(df[col]))

    return features_range

# %%
get_value_range(X)
# Out:
# {'Air Pollution': (1, 8),
#  'Alcohol use': (1, 8),
#  'Dust Allergy': (1, 8),
#  'OccuPational Hazards': (1, 8),
#  'Genetic Risk': (1, 7),
#  'chronic Lung Disease': (1, 7),
#  'Balanced Diet': (1, 7),
#  'Obesity': (1, 7),
#  'Smoking': (1, 8),
#  'Passive Smoker': (1, 8),
#  'Chest Pain': (1, 9),
#  'Coughing of Blood': (1, 9),
#  'Fatigue': (1, 9),
#  'Dry Cough': (1, 7)}

# %%
# load the saved fitted scaler
from pickle import load
with open('../model/fitted_std_scaler.pkl', 'rb') as f:
    std_scaler = load(f)

# %%
# # save the fitted label encoder
# from pickle import dump
# with open('../model/fitted_label_encoder.pkl', 'wb') as f:
#     dump(labelencoder, f)

# %%
from pickle import load
with open('../model/fitted_label_encoder.pkl', 'rb') as f:
    label_encoder = load(f)

# %%
def get_predictions(test_data, model, scaler, encoder):
    return encoder.inverse_transform(model.predict(scaler.transform(test_data)))

# %%
import random

feature_values = {'Air Pollution': [random.choice(range(1, 8))], 'Alcohol use': [random.choice(range(1, 8))], 
                  'Dust Allergy': [random.choice(range(1, 8))], 'OccuPational Hazards': [random.choice(range(1, 8))], 
                  'Genetic Risk': [random.choice(range(1, 7))], 'chronic Lung Disease': [random.choice(range(1, 7))], 
                  'Balanced Diet': [random.choice(range(1, 7))], 'Obesity': [random.choice(range(1, 7))], 
                  'Smoking': [random.choice(range(1, 8))], 'Passive Smoker': [random.choice(range(1, 8))], 
                  'Chest Pain': [random.choice(range(1, 9))], 'Coughing of Blood': [random.choice(range(1, 9))], 
                  'Fatigue': [random.choice(range(1, 9))], 'Dry Cough': [random.choice(range(1, 7))]}

# %%
test_data = pd.DataFrame(feature_values)

# %%
print(f'Lung Cancer Susceptibility: {get_predictions(test_data, knc_loaded, std_scaler, label_encoder)[0]}')
# Out:
# Lung Cancer Susceptibility: Medium

# %%
from shap import KernelExplainer, LinearExplainer, TreeExplainer, sample

# %%
dt_explainer = TreeExplainer(dtc)
dt_shap_vals = dt_explainer.shap_values(x_train_new)
rf_explainer = TreeExplainer(rfc)
rf_shap_vals = rf_explainer.shap_values(x_train_new)

# %%
svm_explainer = KernelExplainer(svc.predict, sample(x_train_new, 100))
svm_shap_vals = svm_explainer.shap_values(x_test_new)
# Out:
#   0%|          | 0/250 [00:00<?, ?it/s]

# %%
lr_explainer = LinearExplainer(lr, x_train_new)
lr_shap_vals = lr_explainer.shap_values(x_test_new)

# %%
import shap
shap.summary_plot(dt_shap_vals, x_train_new, plot_type='bar')
plt.savefig('../reports/shap_decision_tree_summary_plot.jpg')
plt.clf()

# %%
shap.summary_plot(svm_shap_vals, x_test_new, plot_type='bar')
plt.savefig('../reports/shap_SVM_summary_plot.jpg')
plt.clf()

# %%
shap.summary_plot(rf_shap_vals, x_train_new, plot_type='bar')
plt.savefig('../reports/shap_random_forest_summary_plot.jpg')
plt.clf()

# %%
shap.summary_plot(lr_shap_vals, x_train_new, plot_type='bar')
plt.savefig('../reports/shap_logistic_regression_summary_plot.jpg')
plt.clf()
